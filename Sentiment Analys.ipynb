# %%
import pandas as pd

# Membaca file csv dalam folder dataset
df = pd.read_csv(r"C:\Users\Fathu Rizka\Downloads\TestCase\dataset\twitter_data.csv", sep="\t")

# Menampilkan 5 baris pertama
df.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1340330565157801985  1340330565157801985  2020-12-19 23:18:03 WIB
# 1  1340330520383635457  1340329916248682497  2020-12-19 23:17:52 WIB
# 2  1340330406286032899  1340049506671370240  2020-12-19 23:17:25 WIB
# 3  1340330386706993152  1340330386706993152  2020-12-19 23:17:20 WIB
# 4  1340330220486676480  1340330220486676480  2020-12-19 23:16:41 WIB
#
#          date      time  timezone              user_id        username  \
# 0  2020-12-19  23:18:03       700            233033398         ozy_pwt
# 1  2020-12-19  23:17:52       700   903972264168767488  gorengankruncy
# 2  2020-12-19  23:17:25       700  1087526097686679552    genialariefw
# 3  2020-12-19  23:17:20       700  1105417375451570176        simobawa
# 4  2020-12-19  23:16:41       700            542565359       mathsoul1
#
#              name  place  ... geo source user_rt_id user_rt retweet_id  \
# 0     Ayahnya ARA    NaN  ... NaN    NaN        NaN     NaN        NaN
# 1       gorengan🏴    NaN  ... NaN    NaN        NaN     NaN        NaN
# 2  Genial Arief W    NaN  ... NaN    NaN        NaN     NaN        NaN
# 3     Semutyreng🐜    NaN  ... NaN    NaN        NaN     NaN        NaN
# 4  pribumiOPOSISI    NaN  ... NaN    NaN        NaN     NaN        NaN
#
#                                             reply_to  retweet_date  translate  \
# 0                                                 []           NaN        NaN
# 1  [{'screen_name': 'Dahnilanzar', 'name': 'Dahni...           NaN        NaN
# 2  [{'screen_name': 'tifsembiring', 'name': 'Tifa...           NaN        NaN
# 3                                                 []           NaN        NaN
# 4                                                 []           NaN        NaN
#
#   trans_src trans_dest
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106902 entries, 0 to 106901
# Data columns (total 36 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               106902 non-null  int64
#  1   conversation_id  106902 non-null  int64
#  2   created_at       106902 non-null  object
#  3   date             106902 non-null  object
#  4   time             106902 non-null  object
#  5   timezone         106902 non-null  int64
#  6   user_id          106902 non-null  int64
#  7   username         106902 non-null  object
#  8   name             106902 non-null  object
#  9   place            0 non-null       float64
#  10  tweet            106902 non-null  object
#  11  language         106902 non-null  object
#  12  mentions         106902 non-null  object
#  13  urls             106902 non-null  object
#  14  photos           106902 non-null  object
#  15  replies_count    106902 non-null  int64
#  16  retweets_count   106902 non-null  int64
#  17  likes_count      106902 non-null  int64
#  18  hashtags         106902 non-null  object
#  19  cashtags         106902 non-null  object
#  20  link             106902 non-null  object
#  21  retweet          106902 non-null  bool
#  22  quote_url        26444 non-null   object
#  23  video            106902 non-null  int64
#  24  thumbnail        8279 non-null    object
#  25  near             0 non-null       float64
#  26  geo              0 non-null       float64
#  27  source           0 non-null       float64
#  28  user_rt_id       0 non-null       float64
#  29  user_rt          0 non-null       float64
#  30  retweet_id       0 non-null       float64
#  31  reply_to         106902 non-null  object
#  32  retweet_date     0 non-null       float64
#  33  translate        0 non-null       float64
#  34  trans_src        0 non-null       float64
#  35  trans_dest       0 non-null       float64
# dtypes: bool(1), float64(11), int64(8), object(16)
# memory usage: 28.6+ MB

# %%
df.isnull().sum()
# Out:
# id                      0
# conversation_id         0
# created_at              0
# date                    0
# time                    0
# timezone                0
# user_id                 0
# username                0
# name                    0
# place              106902
# tweet                   0
# language                0
# mentions                0
# urls                    0
# photos                  0
# replies_count           0
# retweets_count          0
# likes_count             0
# hashtags                0
# cashtags                0
# link                    0
# retweet                 0
# quote_url           80458
# video                   0
# thumbnail           98623
# near               106902
# geo                106902
# source             106902
# user_rt_id         106902
# user_rt            106902
# retweet_id         106902
# reply_to                0
# retweet_date       106902
# translate          106902
# trans_src          106902
# trans_dest         106902
# dtype: int64

# %%
df.fillna("Unknown", inplace=True)  # Mengisi dengan "Unknown"
# atau
df.dropna(inplace=True)  # Menghapus baris yang mengandung NaN
# Out:
# C:\Users\Fathu Rizka\AppData\Local\Temp\ipykernel_14592\585439121.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("Unknown", inplace=True)  # Mengisi dengan "Unknown"

# %%
df.isnull().sum()
# Out:
# id                 0
# conversation_id    0
# created_at         0
# date               0
# time               0
# timezone           0
# user_id            0
# username           0
# name               0
# place              0
# tweet              0
# language           0
# mentions           0
# urls               0
# photos             0
# replies_count      0
# retweets_count     0
# likes_count        0
# hashtags           0
# cashtags           0
# link               0
# retweet            0
# quote_url          0
# video              0
# thumbnail          0
# near               0
# geo                0
# source             0
# user_rt_id         0
# user_rt            0
# retweet_id         0
# reply_to           0
# retweet_date       0
# translate          0
# trans_src          0
# trans_dest         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(18276)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                  id  conversation_id  timezone       user_id  replies_count  \
# count  8.862600e+04     8.862600e+04   88626.0  8.862600e+04   88626.000000
# mean   1.340012e+18     1.339859e+18     700.0  7.860971e+17       0.584321
# std    1.246808e+14     8.707843e+15       0.0  5.512114e+17       9.488630
# min    1.339782e+18     3.265400e+16     700.0  1.029500e+07       0.000000
# 25%    1.339923e+18     1.339904e+18     700.0  2.460536e+09       0.000000
# 50%    1.339962e+18     1.339943e+18     700.0  1.077964e+18       0.000000
# 75%    1.340114e+18     1.340077e+18     700.0  1.245635e+18       0.000000
# max    1.340333e+18     1.340333e+18     700.0  1.340326e+18     770.000000
#
#        retweets_count   likes_count         video
# count    88626.000000  88626.000000  88626.000000
# mean         1.736804      3.179191      0.076783
# std         23.803006     50.803899      0.266249
# min          0.000000      0.000000      0.000000
# 25%          0.000000      0.000000      0.000000
# 50%          0.000000      0.000000      0.000000
# 75%          1.000000      1.000000      0.000000
# max       2199.000000   4520.000000      1.000000

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(12, 8), bins=30, edgecolor="black")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pilih hanya kolom numerik
df_numeric = df.select_dtypes(include=["number"])

plt.figure(figsize=(10, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="sentiment", data=df, palette="Set2")
plt.title("Distribusi Sentimen")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 plt.figure(figsize=(6, 4))
# ----> 2 sns.countplot(x="sentiment", data=df, palette="Set2")
#       3 plt.title("Distribusi Sentimen")
#       4 plt.show()
#
# File c:\Users\Fathu Rizka\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# File c:\Users\Fathu Rizka\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)     64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)     76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File c:\Users\Fathu Rizka\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\Fathu Rizka\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\Fathu Rizka\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\Fathu Rizka\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `sentiment` for `x`. An entry with this name does not appear in `data`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.countplot(x=df["language"], order=df["language"].value_counts().index, palette="coolwarm")
plt.xticks(rotation=45)
plt.title("Distribusi Bahasa dalam Tweet")
plt.show()
# Out:
# C:\Users\Fathu Rizka\AppData\Local\Temp\ipykernel_14592\237556429.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["language"], order=df["language"].value_counts().index, palette="coolwarm")

# %%
import matplotlib.pyplot as plt

df["created_at"] = pd.to_datetime(df["created_at"], errors="coerce")  # Pastikan kolom datetime
df["date"] = df["created_at"].dt.date  # Ambil tanggal saja

# Hitung jumlah tweet per hari
tweet_volume = df.groupby("date").size()

plt.figure(figsize=(12, 6))
tweet_volume.plot(kind="line", color="blue")
plt.title("Tweet Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Tweets")
plt.show()
# Out:
# C:\Users\Fathu Rizka\AppData\Local\Temp\ipykernel_14592\1589357984.py:3: FutureWarning: Parsed string "2020-12-19 23:18:03 WIB" included an un-recognized timezone "WIB". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["created_at"] = pd.to_datetime(df["created_at"], errors="coerce")  # Pastikan kolom datetime

# %%
# Top 10 pengguna paling aktif
top_users = df["username"].value_counts().head(10)
print(top_users)

# Distribusi jumlah retweets dan likes
df[["retweets_count", "likes_count"]].hist(bins=30, figsize=(10, 5), edgecolor="black")
plt.show()
# Out:
# username
# kunbryansmith      233
# panji93757244      229
# setiadiyudizaza    227
# just_kiz           216
# syaikhumochtar     210
# armanhlp           203
# kucingkampunq      202
# cengdem01          195
# elinmoenik2        194
# kopralmacan        185
# Name: count, dtype: int64

# %%
from textblob import TextBlob

# Fungsi untuk mendapatkan sentimen
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df["sentiment"] = df["tweet"].apply(get_sentiment)

# Plot distribusi sentimen
sns.countplot(x=df["sentiment"], palette="coolwarm")
plt.title("Distribusi Sentimen")
plt.show()
# Out:
# C:\Users\Fathu Rizka\AppData\Local\Temp\ipykernel_14592\3372259670.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["sentiment"], palette="coolwarm")

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download("vader_lexicon")

sia = SentimentIntensityAnalyzer()

df["emotion_score"] = df["tweet"].apply(lambda x: sia.polarity_scores(x)["compound"])

# Plot distribusi emosi
sns.histplot(df["emotion_score"], bins=20, kde=True, color="purple")
plt.title("Distribusi Skor Emosi dalam Tweet")
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Fathu
# [nltk_data]     Rizka\AppData\Roaming\nltk_data...

# %%
from collections import Counter

mentions = df["mentions"].dropna().str.split().sum()  # Ekstrak mentions
mention_counts = Counter(mentions).most_common(10)  # Top 10 mentions
print(mention_counts)
# Out:
# [('[]', 86596), ("'name':", 5882), ("'id':", 5882), ("{'screen_name':", 3852), ("[{'screen_name':", 2030), ('human', 592), ("'un", 588), ("rights',", 525), ("'unhumanrights',", 522), ("'69231187'},", 380)]

# %%
top_retweeted = df.groupby("user_rt")["retweets_count"].sum().sort_values(ascending=False).head(10)
print(top_retweeted)
# Out:
# user_rt
# Unknown    153926
# Name: retweets_count, dtype: int64

# %%
top_retweeted = df.groupby("user_rt")["retweets_count"].sum().sort_values(ascending=False).head(10)
print(top_retweeted)
# Out:
# user_rt
# Unknown    153926
# Name: retweets_count, dtype: int64

# %%
import networkx as nx

G = nx.DiGraph()

# Tambahkan node dan edge berdasarkan retweet
for _, row in df.dropna(subset=["user_rt"]).iterrows():
    G.add_edge(row["user_rt"], row["username"])  # A -> B (B me-retweet A)

plt.figure(figsize=(10, 6))
nx.draw(G, with_labels=True, node_color="lightblue", edge_color="gray", node_size=500, font_size=8)
plt.title("Social Network Retweet Graph")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# Buat Directed Graph (Graf Terarah)
G = nx.DiGraph()

# Tambahkan node dan edge berdasarkan retweet
for _, row in df.dropna(subset=["user_rt"]).iterrows():
    G.add_edge(row["user_rt"], row["username"])  # A -> B (B me-retweet A)

# Ambil 50 node dengan derajat tertinggi (paling banyak koneksi)
top_users = sorted(G.degree, key=lambda x: x[1], reverse=True)[:50]
top_nodes = [node[0] for node in top_users]
G_filtered = G.subgraph(top_nodes)

# Ukuran node berdasarkan jumlah koneksi (degree)
node_size = [G_filtered.degree(n) * 100 for n in G_filtered.nodes]

# Gunakan warna berdasarkan degree centrality (koneksi paling banyak)
centrality = nx.degree_centrality(G_filtered)
node_color = [centrality[n] for n in G_filtered.nodes]

# Plot graf dengan layout yang lebih jelas
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G_filtered, k=0.5)  # Layout lebih rapi
nx.draw(G_filtered, pos, with_labels=True, node_size=node_size, node_color=node_color, cmap="coolwarm", edge_color="gray", font_size=8)
plt.title("Social Network Analysis - Retweet Interaction", fontsize=14)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Membuat Directed Graph
G = nx.DiGraph()

# Menambahkan edge berdasarkan retweet
for _, row in df.dropna(subset=["user_rt"]).iterrows():
    G.add_edge(row["user_rt"], row["username"])  # A -> B (B me-retweet A)

# Menghitung Degree Centrality
degree_centrality = nx.degree_centrality(G)

# Menampilkan Top 10 Akun dengan Degree Centrality Tertinggi
top_influencers = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:10]

print("🔹 Top 10 Influencers (Degree Centrality):")
for user, centrality in top_influencers:
    print(f"{user}: {centrality:.4f}")

# Visualisasi Graf dengan Ukuran Node Berdasarkan Degree Centrality
plt.figure(figsize=(12, 8))
node_size = [v * 3000 for v in degree_centrality.values()]  # Perbesar ukuran node
nx.draw(G, with_labels=True, node_color="lightblue", edge_color="gray", node_size=node_size, font_size=8)
plt.title("Social Network Retweet Graph (Degree Centrality)")
plt.show()
# Out:
# 🔹 Top 10 Influencers (Degree Centrality):
# Unknown: 1.0000
# ozy_pwt: 0.0001
# gorengankruncy: 0.0001
# genialariefw: 0.0001
# simobawa: 0.0001
# mathsoul1: 0.0001
# dedebastian17: 0.0001
# samguppymlg: 0.0001
# joe_wiet: 0.0001
# edypran53614825: 0.0001
